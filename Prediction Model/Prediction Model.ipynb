# %% [markdown]
# # Prediction Model

# %% [markdown]
# ## Importing libraries and files

# %%
import pandas as pd
import numpy as np
import math
from os.path import join
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import  TfidfVectorizer
from sklearn.naive_bayes import GaussianNB
from IPython.display import display, Markdown
from random import randint


base_dataset = pd.read_csv(join("data", "dataset.csv"))

# %% [markdown]
# ## Creating datasets

# %%
raw_x_train, raw_x_test, y_train, y_test = train_test_split(
    base_dataset["Title"],
    base_dataset["Fact Check"],
    test_size=0.2
)

print(f"Train sample size: {len(raw_x_train)}")
print(f"Test sample size: {len(raw_x_test)}")

print(raw_x_train.head(1))
print(raw_x_test.head(1))
# Out:
# Train sample size: 4687
# Test sample size: 1172
# 3400    Do These Photographs Show a Homeless Veteran D...
# Name: Title, dtype: object
# 1696    No, This Isn't a Real Headline About Cuba and ...
# Name: Title, dtype: object

# %% [markdown]
# ## Formatting data

# %%
vectorizer = TfidfVectorizer()

x_train = vectorizer.fit_transform(raw_x_train)
x_test = vectorizer.transform(raw_x_test)

display(x_train)
# Out:
# <4687x8756 sparse matrix of type '<class 'numpy.float64'>'
# 	with 41903 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #  Train Naive Bayes

# %%
gnb = GaussianNB()
gnb.fit(x_train.toarray(), y_train)

y_pred = gnb.predict(x_test.toarray())

preds = list(zip(raw_x_test, y_pred))
diffs = list(zip(y_test, y_pred))
for pred, diff in zip(preds, diffs):
    print(pred, diff)
# Out:
# ("No, This Isn't a Real Headline About Cuba and Woodchippers", True) (False, True)
# ("Are Human Fetuses 'Taiwan's Hottest Dish'?", False) (True, False)
# ('Christopher John Mineo, Jr', True) (False, True)
# ("Sylvester Stallone Turned Down Work with Robert De Niro Over His 'Wokeness'?", False) (False, False)
# ('The Beatles Posed with Decapitated Baby Dolls in Real Album Cover Photo?', True) (True, True)
# ('Pig Fish', True) (False, True)
# ('Is This a Hedgehog Skeleton?', True) (True, True)
# ('Did Malia Obama Cause 24 Classmates to Be Expelled for Praying on Campus?', False) (False, False)
# ('Is There a Dedicated Hall & Oates Phone Line?', False) (True, False)
# ("Did MyPillow CEO Mike Lindell Say His Social Network Would Ban 'Taking God's Name in Vain'?", False) (True, False)
# ("Did Trump Say 'Laziness Is a Trait in Blacks; No Black President Again Any Time Soon'?", False) (False, False)
# ('Did First COVID-19 Vaccine Recipient Suspiciously Appear in News Report Months Earlier?', False) (False, False)
# ("Did Ayanna Pressley Tweet, 'IQ Is a Measure of Whiteness'?", False) (False, False)
# ('Are These Troops Guarding the Lincoln Memorial?', False) (True, False)
# ("Was George Zimmerman Found Dead After Posting Pics of Trayvon Martin's Body?", True) (False, True)
# ('Walmart Thanksgiving/Black Friday Coupon Scams', False) (False, False)
# ("Is This Santa's Phone Number?", True) (False, True)
# ('Mysterious Tree in India', True) (False, True)
# ("Did Mike Pence Tweet on Jan. 6 That Those Involved 'Will Be Prosecuted to the Fullest Extent of the Law'?", True) (True, True)
# ('Did Mark Zuckerberg Post About Orgies on Little St. James Island?', True) (False, True)
# ('Was This Woman Flogged for Drinking Beer in Iran?', True) (True, True)
# ('Is the Florida Homework Assignment About Trump and Media Bias Real?', False) (True, False)
# ('Biden Finished 76th Academically in a Class of 85 at Syracuse University College of Law in 1968?', True) (True, True)
# ('Chipotle $100 Gift Card Giveaway', True) (True, True)
# ('Sinking Feeling', False) (False, False)
# ('Are Women Using Their Menstrual Blood as Face Masks?', False) (False, False)
# ("Are Texas Voting Machines Switching People's Votes?", False) (False, False)
# ('Does a Photograph Show Rep. Eric Swalwell With Alleged Chinese Spy?', False) (True, False)
# ('Was the Last NYC Pay Phone Really Removed?', False) (False, False)
# ('Was Barack Obama President During Hurricane Katrina?', True) (False, True)
# ('Yes, Astronaut Buzz Aldrin Punched a Conspiracy Theorist', False) (True, False)
# ('Did 62°C Temperatures in Kuwait Cause Trees to Burst into Flames?', True) (False, True)
# ("Did Ivanka Trump Say, 'Let's Ask What We Can Do for My Dad'?", True) (False, True)
# ("Did a New Study Show That Marijuana Leads to a Complete Remission of Crohn's Disease?", True) (False, True)
# ('Did the 82nd Airborne Division Receive Word They Are Being Deployed to the Border?', False) (False, False)
# ("Did Amazon's Alexa Predict WWIII Will Begin in November 2023?", False) (False, False)
# ("Does Lyft Have a Safety Feature That 'Checks in' When Riders Go Off Route?", True) (True, True)
# ('Is This a Photograph of Tree of Life Synagogue Shooting Victim Rose Mallinger?', False) (True, False)
# ('Did the Kalinin K-7 Heavy Bomber Appear in Actual Color Photos?', True) (True, True)
# ("Minnesota Vikings' Stadium Going Meat-Free?", False) (False, False)
# ('Shark Attack', True) (False, True)
# ('Did 4 Democratic Senators Turn Republican Because They Oppose Impeachment?', False) (False, False)
# ("Did a Florida Chinese Restaurant's Sign Read 'F*** DeSantis'?", True) (False, True)
# ("Recycled Video Does Not Show Wagner Chief Prigozhin's Plane Crash", False) (True, False)
# ('Did Obama Foundation Share Pic of George Floyd 9 Days Before He Died?', True) (False, True)
# ('Herman Cain, Ben Shapiro: Is This an Authentic Image from Newsmax Broadcast?', False) (True, False)
# ('Is Facebook Deleting an Image of a Cross Carved to Honor Fallen Firefighters?', True) (False, True)
# ("Is This a 'Polar Vortex' in Chicago?", True) (True, True)
# ('Did a Meteor Fall Into a Volcano?', True) (True, True)
# ('Did Biden Pull Down His Mask at 9/11 Ceremony?', False) (True, False)
# ("Was the Queen's Golden Piano First Owned by Saddam Hussein?", True) (False, True)
# ("Post with Bible Verse Labeled by Facebook as 'Sensitive Content'", True) (True, True)
# ('Does This Video Show a Vampire Squid Skimming Over the Ocean Floor?', True) (True, True)
# ('Is This a Photograph of Robert Mueller in Vietnam?', True) (True, True)
# ("Microsoft Announced It Will Disable Computers of Users Who Share 'Non-Mainstream Content' Online?", False) (False, False)
# ('Your Christmas Tree Is (Probably) Not Full of Lyme Disease Bearing Ticks', True) (False, True)
# ('Did Ilhan Omar Host a Flag-Burning Party?', True) (False, True)
# ('Did the KKK March With a Trump-Pence Sign?', True) (False, True)
# ('Antifa Member Photographed Beating Police Officer?', True) (False, True)
# ("Did a Movie Begin with an 'Unlikable Female Protagonist' Warning?", False) (True, False)
# ('Does This Video Capture a Weather Reporter Slapped in the Face by a Large Fish?', False) (True, False)
# ('Did Anthony Scaramucci Post a Sexually Explicit Tweet in 2009?', True) (False, True)
# ("Donald Trump's Harvard Rejection Letter", False) (False, False)
# ('Deleted Tamir Rice Photo', True) (False, True)
# ("Yes, Lauren Boebert Called for Biden's Impeachment With the Slogan 'Imeach Biden'", False) (True, False)
# ('No, Ted Cruz Did Not Threaten to Deport Beyoncé', False) (False, False)
# ('Rowan Atkinson Death Hoax', False) (False, False)
# ('Did April the Giraffe Die?', False) (True, False)
# ('$75 Bed Bath & Beyond Coupon?', False) (True, False)
# ("Did Pepsi 'Admit' Their Sodas Contain Cancer-Causing Ingredients?", False) (False, False)
# ("Did Alexandria Ocasio-Cortez Declare 'I Have a Very Good Brain'?", False) (False, False)
# ('Pic Shows Electric Vehicles That Failed In German Winter Storm?', False) (True, False)
# ('Real Picture of Trump Wearing Military Garb in 1964?', True) (True, True)
# ('Jesse Owens and Hitler Shook Hands at the 1936 Summer Olympics?', True) (False, True)
# ('Was this Elephant Carved out of Stone in India?', True) (False, True)
# ('Iwon Chain Letter', False) (False, False)
# ('Fetal Footprint', False) (False, False)
# ('Was Parler Hacked in November 2020?', False) (False, False)
# ("Does a 'Welcome to Kansas City' Sign Contain an Unfortunate Typo?", False) (False, False)
# ('Is This a Real Photo of a Lighthouse with a Massive Wave Hitting It?', True) (True, True)
# ("Bernie Sanders Supporters Chant 'English Only' at Dolores Huerta in Nevada?", True) (False, True)
# ("Are These Aerial Photos of Australia's Freedom Convoy?", False) (True, False)
# ('The Follower', True) (True, True)
# ("Was the US Ranked the '118th Safest Country' in the World in 2019?", True) (False, True)
# ('Offutt Air Force Base', False) (True, False)
# ('Does Viral Pic Show Jon Bon Jovi Washing Dishes at His Restaurant?', True) (True, True)
# ('Does This Picture Show a Case of Hyperdontia?', True) (False, True)
# ('Did Vladimir Putin Rescue an Injured Donald Trump from the Viet Cong During the Vietnam War?', True) (False, True)
# ('Is This President Trump With a Controversial Russian Lawyer?', True) (False, True)
# ('Did Henry Kissinger Turn Down an OpenAI Board Seat Just Days Before He Died?', False) (False, False)
# ('Did Alexandria Ocasio-Cortez Submit a Bill that Bans Open Carrying of Guns?', True) (False, True)
# ('Are These the Northern Lights Seen From Space?', False) (True, False)
# ('Officer Who Shot Alton Sterling Pictured at KKK Rally', False) (False, False)
# ('Drug Law Lobbying by Corrections Corporation of America', True) (False, True)
# ('Was an Alien Caught on the Kerala, Karnataka Border?', True) (True, True)
# ('Spam Oreos? Another Fake Flavor Goes Viral', True) (False, True)
# ("Did Monica Lewinsky Offer to 'Take One For (the) Team' to Get Trump Impeached?", False) (False, False)
# ("Is This a Photograph of Joe Biden's House?", True) (True, True)
# ("Did Trump Hang a Photograph of the Women's March at the White House?", False) (False, False)
# ("A Baby Turtle 'Enjoys a Cleaning' in This Viral Vid?", True) (False, True)
# ('Was a Homeless Couple Found Living in a Walmart Attic?', False) (False, False)
# ('Facebook FanCheck', True) (False, True)
# ("Was 'Hang Mike Pence' Chanted at Capitol Riot?", False) (True, False)
# ("Did a Vermont Woman Post a Joke About Trump 'Bringing Back Slavery'?", False) (True, False)
# ('Does Video Show Athletes Fainting Due to COVID-19 Vaccine?', True) (True, True)
# ('Is Amazon Offering Free 1-Day Shipping for Ballots?', True) (False, True)
# ('Did Migrants Destroy a Car in Italy?', True) (False, True)
# ('Is This a Video of 7,000 Fireworks Going Off in San Diego in 2012?', False) (True, False)
# ("Did Rep. Alexandria Ocasio-Cortez Say it Was 'Wrong' for Billionaires to Exist?", False) (False, False)
# ("Do '1 in 4' Women Undergo an Abortion in Their Lifetime?", False) (True, False)
# ('Did Facebook Flag the Declaration of Independence as Hate Speech?', False) (False, False)
# ('Albino Moose', True) (False, True)
# ('New Plymouth Twister Photo', False) (False, False)
# ('Does a Video Show an Armed Robot Turning on Humans?', True) (False, True)
# ('Did Betsy DeVos Demand That Classroom Globes Be Flattened?', False) (False, False)
# ('Are More People Killed By Donkeys Than Airplane Crashes Annually?', True) (False, True)
# ("'Hijack This' Photo", False) (True, False)
# ('Are These Real Videos of Babies at Drag Shows?', True) (True, True)
# ("Did the White House Delete an Unflattering 'Orange Face' Photo of Trump?", False) (False, False)
# ("Donald Trump Doesn't Salute the Flag?", True) (False, True)
# ('Did ODNI Photoshop the Cover of a Diversity Report?', False) (True, False)
# ('Was a Woman Killed by a Frozen Shaft of Urine?', True) (False, True)
# ('Did the Obama Administration Remove USPS Mailboxes?', False) (True, False)
# ('Has Italy Stopped Treating the Elderly in the COVID-19 Pandemic?', False) (False, False)
# ('Does a New Tattoo Ink Allow People With Diabetes to Monitor Their Blood Sugar Levels?', True) (True, True)
# ("No, Those Puncture Holes in Crayola Bath Dropz Packaging Aren't Caused by Drug Users", False) (False, False)
# ('Big Lots Closing?', False) (False, False)
# ("Did Russian Copper Company Buy Up 70K Copies of Don Trump, Jr.'s New Book?", False) (False, False)
# ('FALSE: Facebook Appeal for Boy with Massive Tumor', False) (False, False)
# ("Did Boebert Praise Taliban for 'Building Back Better'?", True) (True, True)
# ("Did Barnes and Noble Market a Parody of Trump's Presidency as a Children's Book?", False) (False, False)
# ('Michelle Obama Finally Releases Photos of Herself Pregnant?', False) (False, False)
# ("Real Photos of Extinct 'Dragons' of North America?", False) (False, False)
# ('Is Story Land Closing?', True) (False, True)
# ('Was Accused Russian Spy Mariia Butina Photographed in the Oval Office?', False) (False, False)
# ("Genuine Photo of Israeli Demonstrator Holding 'Kill Them All' Sign?", True) (True, True)
# ('Is Snapchat Building a Facial Recognition Database for the Feds?', False) (False, False)
# ('Death of Rachel Hoffman', False) (True, False)
# ('Did Rand Paul Get COVID-19 Vaccination in Viral Photo?', False) (True, False)
# ("Yes, UVA Told Students to 'RUN HIDE FIGHT' During Active Shooter Situation", False) (True, False)
# ('Are U.S. Schools Buying Prayer Rugs for Muslim Students?', False) (False, False)
# ('Does Dolph Lundgren Have Multiple Scientific Degrees?', False) (True, False)
# ('Did Conor McGregor and Floyd Mayweather Sign for a Rematch?', True) (False, True)
# ("Did Ashton Kutcher's Software Help Rescue 6,000 Children from Sex Trafficking?", True) (False, True)
# ('The Ghost Under the Bed', False) (False, False)
# ("Does This Photo Show a Cat's Tongue Under a Microscope?", True) (True, True)
# ('Does This Photograph Show the Water Filtration Power of Oysters?', True) (True, True)
# ('Radiohead Fans Left Red-Faced After Applauding Tuning Session?', True) (False, True)
# ('Bruce Jenner IS Transitioning to Becoming a Woman?', True) (False, True)
# ("Did Hillary Clinton Ask for 'Huge' Donations to the Clinton Foundation for Hurricane Dorian Victims?", True) (False, True)
# ('Is Facebook Deleting an Image of a Cross Carved to Honor Fallen Firefighters?', True) (False, True)
# ('Those Vintage Photos of Scandinavian Airlines Meals Are Real', True) (True, True)
# ("Is Pence Taking Trump's Coronavirus Tests for Him?", True) (False, True)
# ('Did a Priest in France Slap a Baby During a Baptism Ceremony?', True) (True, True)
# ('Did Facebook Shut Down an AI Experiment Because Chatbots Developed Their Own Language?', True) (False, True)
# ('Did the US Surgeon General Recommend the Public Not Wear Masks?', False) (False, False)
# ('Did Biden Twice Vote To Tax Social Security While in the Senate?', False) (True, False)
# ("Did Fox News Post Staged Photo of Soldiers During Trump's 2019 Afghanistan Visit?", False) (False, False)
# ("Did Draymond Green Wear a 'F*ck It, Die Then' Vaccine Shirt?", False) (False, False)
# ("Was 'World's Largest Log Cabin' Oregon's Forestry Building?", True) (True, True)
# ('Welcome to Kenya, Birthplace of Barack Obama', True) (False, True)
# ('Welfare Prenuptial', True) (False, True)
# ('Did NYC Mayor Bill de Blasio Once Support the Sandinista Govt. in Nicaragua?', False) (True, False)
# ("Hey 'Crypto Bro's,' That McDonald's Billboard is Fake", True) (False, True)
# ('Was the CPAC 2021 Stage Intentionally Shaped Like a Nazi Symbol?', False) (False, False)
# ('Real Photo of Marilyn Monroe and Elvis Presley Together?', False) (False, False)
# ('Free Pastry Day at Starbucks', True) (True, True)
# ("Immigrants vs. 'Gimmegrants'", True) (False, True)
# ('Real Video of Workers in a Temu Warehouse?', False) (False, False)
# ("Has NASA Called the Image of the Virgin of Guadalupe 'Living'?", False) (False, False)
# ("Did the CDC Recall PCR COVID-19 Tests Because They 'Failed Full Review'?", True) (False, True)
# ("Did Kamala Harris Tweet 'Enjoy the Long Weekend' Before Memorial Day?", True) (True, True)
# ('Crocodile in New Orleans', True) (True, True)
# ('Apple Music is Deleting Files from Personal Computers', False) (False, False)
# ('Yes, 988 Is a Real US Number for Mental Health Crises and Suicidal Thoughts', True) (True, True)
# ('Does This Video Show a Man Ripping the MAGA Hat Off a Trump Supporter?', False) (True, False)
# ('Is This a Real Photo of Ukrainian Soldiers in Front of a Swastika Flag?', True) (True, True)
# ('Did Kurt Russell Share A Poem Opposing the Defunding of Police?', False) (False, False)
# ("Bill O'Reilly Telephone Poll of 25,000 Voters Shows Trump with a Huge Lead?", False) (False, False)
# ("Is This What NATO's Headquarters Looks Like?", False) (True, False)
# ("Did JFK Say Americans Could Be Entrusted with 'Unpleasant Facts'?", True) (True, True)
# ('How Are These Migrants Paying for their Mobile Phones?', True) (True, True)
# ('Meme Accurately Shows Inflation-Driving Profits for 15 Corporations?', False) (False, False)
# ("Idaho Televangelist Ran Off with Congregants' Money After Telling Them Eclipse Would Bring Rapture?", True) (False, True)
# ("Is Using 'Bug Spray' to Get High an Alarming New Trend?", False) (False, False)
# ("Sony Had to Recall Camcorders That Could See Through People's Clothes?", False) (False, False)
# ('Is the COVID-19 Vaccine Vape Cartridge Real?', True) (False, True)
# ("Scouts Are Removing 'God' from Their Oath?", False) (False, False)
# ('Finger Chop Challenge', True) (False, True)
# ('Are NFL Players Protesting Against Police Brutality Absentee Parents Putting Their Children at Risk?', False) (False, False)
# ('Did a Harvard Study Prove That “Unvaccinated Children Pose No Risk” to Other Kids?', False) (False, False)
# ('Can You Text to 83361 to Receive a Free Target Gift Card?', True) (True, True)
# ('Can You Vote Online with a Hashtag?', True) (False, True)
# ('Does This Photo Show a Real Sea Slug?', True) (True, True)
# ("Did 'The Simpsons' Predict Dating Apps?", True) (False, True)
# ('Do These Photographs Show a Tiger Nursing Piglets?', True) (True, True)
# ('Condoleezza Rice and Osama Bin Laden', True) (False, True)
# ('Is Orlando Shooting Hero Imran Yousuf a Muslim?', False) (False, False)
# ('USPS Did Not Issue Bernie Sanders Forever Stamps', False) (False, False)
# ("Is This a 'Lava Moon' Melting into a Waterfall?", True) (False, True)
# ('Greta Thunberg Never Suggested Climate Change Would Wipe Out Humanity by 2023', True) (False, True)
# ('Did the Label of Renuzit Air Freshener Include a Phallic Image?', True) (False, True)
# ('Leonardo DiCaprio Endorses Trump?', False) (False, False)
# ("Did Fox News Report that Trump's Mar-a-Lago Club Received Foreclosure Notice from Deutsche Bank?", True) (False, True)
# ('Are These Rainbow Mountains Real?', True) (False, True)
# ('Hillary Clinton Wore Secret Earpiece During First Presidential Debate?', False) (False, False)
# ('Is State Farm Denying Insurance to Gun Owners?', False) (False, False)
# ('Trisha Yearwood Keto Gummies Weight Loss Ads Are a Scam', True) (True, True)
# ("Did VP Mike Pence Introduce 'Conversion Therapy' Program to Combat Coronavirus?", False) (False, False)
# ('Do These Pics Show Book Burnings in 1933 and 2022?', True) (True, True)
# ("Are Michigan Lawmakers Marking Immigrants' Licenses with Yellow Stars?", False) (False, False)
# ('Real Photo of a Man Standing on Large Pile of Bison Skulls?', True) (True, True)
# ('Did Harvard Pay Elizabeth Warren $400,000 to Teach One Class?', False) (False, False)
# ("Does Microscopic Image Show 'Smiley Faces' in a Blade of Grass?", True) (True, True)
# ('Did a Tornado Pass by a Philadelphia Phillies Game in 2021?', True) (False, True)
# ("Did President Trump Fail to Place His Hand Over His Heart During George H.W. Bush's Funeral?", True) (False, True)
# ("Did Hillary Clinton Tweet This Snarky Response to Russia's Sanctioning Her?", True) (True, True)
# ('Wood Art', True) (True, True)
# ('Human Statue of Liberty', False) (True, False)
# ("Did MSNBC Use a 'Trump Worried About Pecker Leaking' Chyron?", True) (False, True)
# ("Did Mark Twain Say 'Fear the Media, for They Will Steal Your Honor'?", False) (False, False)
# ('Did a Woman Find Human Ashes in a $2 Blue Heart Ornament?', True) (True, True)
# ('Did Twitter Prohibit Making an Accurate Claim About COVID-19 Transmission?', False) (False, False)
# ('Did Sarah Sanders Offer Roseanne Barr a White House Job?', True) (False, True)
# ('Does Pic Show Keanu Eating Ice Cream at a Movie Theater?', False) (True, False)
# ("Did a Doctor Say 'Stop' After Identical Twins Married Identical Twins?", False) (False, False)
# ('Is Aldi Giving Away Free Groceries on Facebook?', True) (True, True)
# ("Is the 'Venezuelan Poodle Moth' Real?", True) (False, True)
# ("Did Keanu Reeves Help Pay for a Stranger's Kidney Transplant with an Envelope of Cash?", True) (False, True)
# ('Red Robin Happy Burger-day Coupon', True) (False, True)
# ('Is This a Photograph of Christine Blasey Ford Partying?', False) (False, False)
# ('Facebook Will End on May 15th, 2013', False) (False, False)
# ("Did an Applebee's 'Adult Spouse' Sign Welcome 'Child Brides'?", False) (False, False)
# ('Does This Photograph Show a Seal Hugging a Beluga Whale?', True) (False, True)
# ("Did Fox News Sign $1B Contract with Roseanne Barr for Show To Rival 'The View'?", False) (False, False)
# ('Bear Hunt', True) (True, True)
# ('Webkinz Murderer', True) (False, True)
# ("Are Vans Shoes Designed to 'Stomp on Jews'?", False) (False, False)
# ('Swedish Girl Refugee Assault', False) (False, False)
# ('Can You Get a Free Bus Ticket by Doing 20 Squats in Romania?', True) (True, True)
# ('Did Ian McKellen Visit Lviv, Ukraine?', True) (True, True)
# ('Is This a Photograph of a Flying Lizard?', True) (False, True)
# ("Did Harvard Admit Michelle Obama's Degrees Are Fake?", False) (False, False)
# ('Did Ari Fleischer Compare Showing ID to Get Vaccinated to Voter ID Laws?', False) (True, False)
# ('Does Viral Video Show Voter Fraud in Atlanta, Georgia?', True) (False, True)
# ("Kari Lake Did Not Concede on Twitter, Despite Tweet from 'Verified' Parody Impersonation Account", False) (False, False)
# ('Is Sean Spicer Wearing Mismatched Shoes?', True) (False, True)
# ('Did Eric Clapton Once Unleash a Racist Rant Onstage?', False) (True, False)
# ('Did Masai Tribespeople Donate 14 Cows to the United States After 9/11?', True) (True, True)
# ("Did MLK Say 'Darkness Cannot Drive Out Darkness; Only Light Can Do That'?", True) (True, True)
# ('The Farm Below the Mountain', False) (False, False)
# ("Did RNC Speaker Abby Johnson Advocate 'Household Voting'?", False) (True, False)
# ("Is the World's 'Most Inconvenient Convenience Store' a Real Place?", True) (True, True)
# ("Did a Muslim Scholar Advocate 'Colonizing' U.S. and Canada with Sharia Law?", False) (False, False)
# ('Can Rapists Sue for Child Custody, While Rape Victims Cannot Sue for Child Support?', False) (False, False)
# ('One of These Dogs Is Not Like the Otters', True) (False, True)
# ('Is the Trump Administration Seeking to Monitor Social Media Accounts of Disability Recipients?', False) (True, False)
# ('Facebook Donations for Little Girl with Distended Abdomen', True) (False, True)
# ('Did a Biplane Buzz a Los Angeles Beach in 1911?', False) (False, False)
# ('Facebook Deleting Inactive Likes?', True) (True, True)
# ('Viral Video Showcases Massive Draft Horse', False) (True, False)
# ('Was Emma González Photographed Swinging an Umbrella at a Truck?', False) (False, False)
# ("'Bear in Walmart' TikTok Video Was Not Recorded in Walmart", True) (False, True)
# ("Two Editions of 'Wall Street Journal' Bear Opposite Headlines About Trump", True) (True, True)
# ("ABC's Dr. Jennifer Ashton Never Endorsed Keto or CBD Gummies for Weight Loss", False) (True, False)
# ('Yes, Photo Shows an Astronaut Giving Himself a Flu Shot in Space', True) (True, True)
# ("Did Bill Burr Philosophize About 'Sleeping on a Futon When You're 30'?", True) (True, True)
# ("Did ABC Hire Tim Allen as Its 'Conservative Programming Consultant'?", False) (False, False)
# ("Did Twitter Label CBC's Account '69% Government-Funded Media'?", True) (True, True)
# ('9-Year-Old Girl Gang-Raped', False) (False, False)
# ('Should Coke Always Be Poured on Wheels When Traveling Alone?', False) (False, False)
# ("Are Migrants 'Free to Leave Detention Centers Any Time'?", True) (False, True)
# ("Was Dick Van Dyke Condemned Over 'Blackface' Appearance in 'Mary Poppins'?", False) (False, False)
# ('Risqué Images on Biscuit Tin', True) (True, True)
# ("Misleading Ad Does Not Show Nelly's Abandoned Mansion", False) (False, False)
# ('Three Former Presidents Mocked Trump on Twitter?', True) (False, True)
# ("Scam in New York City Urges Residents To 'Pre-Register' for COVID-19 Vaccine", False) (True, False)
# ("Elon Musk Fired 'The View' Cast After Acquiring ABC?", False) (False, False)
# ('Did US Gas Prices Drop Below $2 Under Trump?', False) (True, False)
# ("Did Audrey Hepburn Author These 'Beauty Tips'?", False) (False, False)
# ("Did the Secret Service 'Officially Debunk' Hutchinson's Testimony?", True) (False, True)
# ('Did Barack Obama Meet with Malcolm X and Martin Luther King, Jr.?', False) (False, False)
# ("Did Sean Spicer Tweet 'Today Is Dday' On Pearl Harbor Day?", False) (True, False)
# ("No, US Space Force Commander Wasn't Arrested for Treason", False) (False, False)
# ("No, Tucker Carlson Didn't Vow To Kill Himself If the Chiefs Won the Super Bowl", True) (False, True)
# ("Did Ann Coulter Tweet That 'Men Have No Choice But to Rape ...'?", True) (True, True)
# ('If You Used FaceApp, Do Russians Now Own All of Your Photographs?', False) (False, False)
# ('Did the ICE Twitter Account Mysteriously Disappear?', True) (True, True)
# ("McDonald's Supports Chick-fil-A", True) (False, True)
# ('Did Biden Wear a Hard Hat Backwards in Photo Op with Construction Workers?', True) (True, True)
# ('Did Fox News Use an Image of Patti LaBelle During Their Aretha Franklin Tribute?', True) (True, True)
# ("Was 'Duck Dynasty's' Si Robertson Found Dead?", False) (False, False)
# ('Did Barack Obama Visit Arlington Cemetery on Veterans Day?', True) (True, True)
# ('Did Macron Scold Biden at NATO Summit?', True) (True, True)
# ('Did Pope Francis Meet With Bill Clinton and Alexander Soros?', False) (True, False)
# ("Are Facebook Hackers Posting 'Sexual Videos'?", False) (False, False)
# ('Did Senator Chuck Schumer Have an Affair with a Teenager?', False) (False, False)
# ('No, Elon Musk Did Not Offer Tucker Carlson the Job of Twitter CEO', True) (False, True)
# ('Powerball Wealth Sharing Meme', False) (False, False)
# ('Is Facebook Charging a User Fee?', False) (False, False)
# ('Did Patriots Coach Bill Belichick Suspend Team Captain for Anthem Kneeling?', False) (False, False)
# ('Was US Rep. Jim Jordan Suspended From Twitter?', True) (False, True)
# ("Costco and T-Mobile Email Scam Promises 'Exclusive Reward'", True) (True, True)
# ('Is This a Photograph of the Woman Who Modeled for the Statue of Liberty?', False) (False, False)
# ("Was Cory Booker's Son Charged with Assault After Attack on Santa?", False) (False, False)
# ('Did Elizabeth Warren Lie About Her Native American Heritage to Land a Job at Harvard?', False) (False, False)
# ("Was an 'Omicron' Movie Made in the '60s?", True) (False, True)
# ('Did You Lose a Cat?', False) (False, False)
# ("Eli Lilly Did Not Announce Free Insulin, Despite Tweet from 'Verified' Parody Impersonation Account", False) (False, False)
# ('Trump Supporters Wore Diapers at Rallies?', True) (True, True)
# ("'Myspace Tom' Anderson Vanished After Selling His Social Media Company?", False) (False, False)
# ('Was Comedian Michelle Wolf Once Arrested for Bestiality?', True) (False, True)
# ("Did State Farm Cancel Bloomberg's Insurance Over Hillary VP Announcement?", False) (False, False)
# ('Are Children Being Assigned Numbers in Detention Centers?', True) (False, True)
# ('Is There a New, Rare Tick That Burrows Under Your Skin Undetected?', True) (False, True)
# ("Instagram Bans the Phrase 'I Am a Born Again Follower of Jesus'?", False) (False, False)
# ('Did Voters Wear Pearls on Election Day To Honor Kamala Harris?', False) (False, False)
# ("Was 'Doonesbury' Censored by Gannett Newspapers on Feb. 18, 2024?", False) (False, False)
# ('Did a Drunken Sailor Use a Raccoon to Bypass an Ignition Interlock?', False) (False, False)
# ('The Post-Civil War Lives of Robert E. Lee and Jefferson Davis', False) (False, False)
# ('Supreme Court Flip-Flops', False) (True, False)
# ('Does This Photograph Show John McCain with Osama bin Laden?', True) (False, True)
# ('The WHY', True) (False, True)
# ("Hillary Clinton Says Women 'Caved' to Men in Voting Against Her?", True) (False, True)
# ('Tim Kaine Admits to Open Marriage on Twitter', False) (False, False)
# ('Is This a Mug Shot of Tim Allen After a Cocaine Arrest?', True) (True, True)
# ("Canned Pumpkin Isn't Actually Pumpkin?", False) (False, False)
# ('Aborted Fetuses Found in Michigan Dumpster?', False) (True, False)
# ('Is This Meme About Adam Toledo and Kyle Rittenhouse Accurate?', False) (False, False)
# ('Photo Shows Dog Peeing on Sign for Biden, Not Trump', True) (False, True)
# ('Responsible Drinking in Ireland', False) (False, False)
# ('Is This a Real Image of US/UK Strikes on Yemen?', True) (True, True)
# ("Is This 'Before and After' Image of an Earthquake-Damaged Alaskan Road Real?", True) (True, True)
# ('Japan Keeps Islam at Bay?', False) (False, False)
# ("Is This Yet Another Picture of a Melania Trump 'Body Double'?", True) (False, True)
# ('Did Target Partner with Designer Whose Work Includes Satanic Imagery?', False) (True, False)
# ('Obama Crying Like a Psychopath Meme', True) (False, True)
# ('Does Photo Show Dr. Oz Groping Michelle Obama?', True) (False, True)
# ('Do Facebook Donations Recur Every Month Even When a User Chooses a One-Time Contribution?', True) (False, True)
# ('C-130 Flares', True) (True, True)
# ('Blue-Ringed Octopus Has Enough Venom To Kill 26 Adult Humans Within Minutes?', False) (True, False)
# ('Does the Antifa Flag Resemble a Nazi Flag?', True) (False, True)
# ("Did Jane Goodall Compare Donald Trump's Actions to Primate Dominance Behavior?", False) (False, False)
# ('Do These Photos Show Store Returns Full of Donated Toys?', False) (True, False)
# ('The Maiken and the Birth of an Island', True) (True, True)
# ('Did an Onion Headline Mirror a Rep. Greene Tweet?', True) (True, True)
# ('Did 17,000 Ford Plant Jobs in Ohio Go to Mexico?', True) (False, True)
# ('Facebook Terms of Service Violation Scam', False) (False, False)
# ("Did a School Employee Tweet 'Who's Gonna Take One for the Team and Kill Kavanaugh?'", True) (True, True)
# ("Did Rachel Maddow Tweet That Donald Trump Needs to be 'Taken Out?'", False) (False, False)
# ('Facebook: Leaked Roller Coaster Accident Video', True) (False, True)
# ('Agent Orange', False) (True, False)
# ('University of Wisconsin Booklet Photoshopped to Add Black Student', False) (True, False)
# ('Black Fawn', True) (True, True)
# ('Does This Photo Show Skin Punctured by a Needle?', False) (True, False)
# ('Did Larry Walters Fly in a Lawn Chair Attached to Helium Balloons?', True) (True, True)
# ('Does This Dress Change Colors in the Sun?', True) (True, True)
# ("Did Amber Heard Steal 'Talented Mr. Ripley' Lines During Depp Trial?", False) (False, False)
# ('Arizona Rest Area', True) (True, True)
# ('Does a Viral Video Show a Polar Bear Starving to Death?', False) (True, False)
# ("Is Poster Promoting Sequel to '80s Classic Film Series 'The NeverEnding Story' Real?", True) (False, True)
# ('Big Burger', True) (True, True)
# ("Did Tucker Carlson Call Dan Crenshaw 'Eye-Patch McCain'?", False) (True, False)
# ("Did LA Sheriff's Deputies Point Guns at Teenage Assault Victims?", True) (True, True)
# ("Did a Canadian Woman Wear a 'My Legs Are Open for Refugees' Sign?", False) (False, False)
# ('Real or Fake: Is This an Authentic Photo of Trump?', True) (True, True)
# ('Does a Photograph of Kidney Stones Show the Effect of Sodas and Energy Drinks?', False) (True, False)
# ('Is this Really an Electric Car From 1905?', True) (True, True)
# ('Will Looking at This Image Reveal How Stressed You Are?', True) (False, True)
# ('Is Facebook Implementing User Fees?', False) (False, False)
# ('Does This Photograph Show Che Guevara Executing Two Women?', False) (False, False)
# ('Media Quiet About San Antonio Theater Shooting', True) (True, True)
# ('Photo Shows Graves of Protestant Husband and Catholic Wife Not Allowed to Be Buried Together?', False) (True, False)
# ("Is Facebook Kicking People Out of Groups Who Don't Participate?", True) (True, True)
# ('Alan Rickman Rocking Chair Meme', True) (False, True)
# ("Did a Waitress 'Run to the Manager' After Serving a Cop?", False) (False, False)
# ("Did Trump Offer Asylum to 'Lord Nazi Ruso'?", False) (False, False)
# ('Fat Cat', False) (False, False)
# ('Did the Internet Go Dark in D.C. During White House Protests?', False) (False, False)
# ('Did the Girl Scouts Congratulate Amy Coney Barrett on Twitter?', True) (True, True)
# ('Was Madonna in ICU Due to Complications from COVID Vaccine in June 2023?', False) (False, False)
# ('Tim Tebow Tweet', True) (False, True)
# ('Did No US Flags Adorn the Stage at the Detroit Democratic Debate?', False) (False, False)
# ('Did Outback Steakhouse Announce They Are Banning Supporters of President Donald Trump?', False) (False, False)
# ('Were These Monstrous Paws Photographed in Alabama?', True) (False, True)
# ("That's One Way to Stop Road Rage", True) (False, True)
# ("No, Shinzo Abe Didn't Tweet This About Hillary Clinton Before His Death", False) (False, False)
# ('Amber Alert: Andrea Montoya', True) (True, True)
# ('Government Grant Scams', True) (True, True)
# ('Facebook Cold Stone Pregnancy Discount', True) (False, True)
# ('Are Electric Vehicles and Batteries Bad for the Environment?', True) (False, True)
# ('Is Lululemon Recruiting 150 Ambassadors via Instagram?', True) (False, True)
# ("Did a Physician Confirm Hillary Clinton Has Parkinson's Disease?", False) (False, False)
# ('US Illegal Immigration Grew Tenfold from 2017 to 2023?', False) (False, False)
# ('Do These Photographs Show a Guitar Graveyard?', True) (True, True)
# ("Did Trump Write 'Joe, You Know I Won' in Letter to Biden?", True) (False, True)
# ("Does John Travolta Have a 'New Wife'?", False) (False, False)
# ('No, Louisiana Did Not Send 2,000 Alligators to Texas Border', False) (False, False)
# ('Did Roseanne Adopt an African Child After a Racism Kerfuffle?', False) (False, False)
# ("'The Rock' Did Not Promote 'Black Adam' in Tweets About Queen", False) (False, False)
# ("Did Raising Cane's Chicken File for Bankruptcy?", False) (False, False)
# ('Did a Shark Attack on a Missouri Highway?', True) (False, True)
# ("Live-Action 'Cars' Movie Set for Release in 2025?", False) (False, False)
# ("Did Burger King Tweet 'Women Belong in the Kitchen'?", True) (False, True)
# ('Does This Photo Show a Reusable Grocery List from 1920s?', True) (False, True)
# ("Is an 'Obama Don't Separate Me From My Mommy' Protest Sign Real?", True) (True, True)
# ('Giant Sea Spider', True) (False, True)
# ("Bogus 'Now Hiring' Meme Still Circulating on Social Media", True) (False, True)
# ('Does This Photograph Show a Giant Amethyst Geode?', True) (True, True)
# ("Does a Photo Show Nigel Farage with National Front Leader Martin Webster in the '70s?", False) (True, False)
# ("Plane Crash Video 'Disappearing From the Internet'?", True) (False, True)
# ("Is This an Image of 'Child Organ Trafficking Victims' in Thailand?", False) (True, False)
# ('IRS Issuing $8,700 Stimulus Checks to Qualifying Americans in 2024?', True) (False, True)
# ("Alan Jackson Is Not Dead, Despite 'Sad News' Facebook Death Hoax", True) (False, True)
# ('Is the Hammerhead Bat a Real Animal?', True) (True, True)
# ('Lion Snuggles With Cat?', True) (False, True)
# ('Zimbabwe Croc', True) (True, True)
# ('No, George W. Bush Was Not Hanged at Guantanamo Bay', True) (False, True)
# ('Bette Davis Landed Her Biggest Role After Posting an Ad in a Newspaper?', False) (False, False)
# ('Company Anniversary Free Product Scam', True) (True, True)
# ("Clinton Impeachment House Speakers' Sex Scandals", False) (True, False)
# ("Did 'England Ban Fox News Because They Saw It as Propaganda'?", False) (False, False)
# ("Is the 'Aphelion Phenomenon' Causing More Sickness on Earth?", False) (False, False)
# ('Is This a Real Photo of Palestine Before the Founding of Israel?', True) (True, True)
# ('Did Joe Biden Once Advise the Public to Use Shotguns for Self-Defense?', False) (True, False)
# ('Did President Donald Trump Overturn Farm Water Regulations, Causing an E. Coli Outbreak?', False) (False, False)
# ('Did Biden Leave Press Conference Podium as Reporter Asked a Question?', True) (True, True)
# ("Is This a Picture of a 'Tank Silencer'?", True) (True, True)
# ("Was Kelly Clarkson 'Forced' by 'The Voice' to Lose Weight?", False) (False, False)
# ('Utility Bill Payment Scam', False) (True, False)
# ("Is This a Real Picture of Jeff Bezos in Amazon's Office in 1999?", False) (True, False)
# ('Was an Exhausted Funeral Home Employee Cremated by Mistake?', False) (False, False)
# ("Did Sinbad Play a Genie in the 1990s Movie 'Shazaam'?", False) (False, False)
# ("Did 'The Simpsons' Predict Post-Trump Budget Woes?", True) (True, True)
# ('Did a Drunk Crop Duster Drop Manure From the Sky in Kansas?', False) (False, False)
# ('All Dogs Go to Heaven', False) (False, False)
# ('Does a Picture Depict Groomsmen Supporting a Paralyzed Man at His Wedding?', False) (False, False)
# ('Hurricane Hermine Waterspout in North Carolina', True) (False, True)
# ("Fake Anti-Marijuana Picture Rips Off 'Walking Dead' Producer", False) (False, False)
# ('Does Donald Trump Sit Through Meetings of World Leaders Without Notes?', True) (False, True)
# ('The $500 Capital One Gold Card Email Is a Scam', True) (True, True)
# ('Save the Planet with a Small Car', True) (True, True)
# ('Does this Photo Show a Rubber Duck Armada Lost at Sea?', True) (True, True)
# ('Is Starbucks Going Cashless in UK, US, and Canada?', False) (False, False)
# ('MISCAPTIONED: JetBlue Plane Buried by Snow', True) (True, True)
# ('Did Armed Delaware Students Scare Off a School Shooter in 1973?', True) (False, True)
# ('Hillary Clinton and #DraftOurDaughters', True) (False, True)
# ('Does This Image Show a Deceased Grandmother Encased in Resin?', True) (False, True)
# ("Does This Photo Show a Full Crowd at Trump's Tulsa Rally?", True) (True, True)
# ('Does This Photograph Show a Future French Politician as a Shepherd in Morocco?', True) (True, True)
# ('Did Kate Winslet Hold Her Breath For Almost 8 Minutes Underwater?', False) (True, False)
# ('Did This Woman Confuse Spray Foam Insulation for Mousse?', True) (True, True)
# ("Scam Alert: 'Welcome to CarShield' Auto Insurance Emails", True) (True, True)
# ('Ferrero Rocher Chocolates Filled with Maggots?', True) (False, True)
# ('Internet Taxation Moratorium', True) (True, True)
# ('Dad Found Buried Chain After Landscaping His Yard and Instantly Regretted It?', False) (False, False)
# ('Kulula — Flying 101', False) (True, False)
# ('Obama Uses Teleprompter for Speech to 6th Graders?', False) (False, False)
# ('Was Pro Power Saver Endorsed by Elon Musk and Tesla?', True) (True, True)
# ('Did Sgt. Gregory Hayes Kill Two Syrian Refugees for Raping His Daughter?', True) (False, True)
# ("Was McDonald's Worker Fired For Placing His Mixtapes In Happy Meals?", False) (False, False)
# ('Actor Cassi Davis Is Alive, Despite Death Hoax Shared Online', False) (False, False)
# ("Did Melania Trump Plagiarize Michelle Obama's Statement on Women's History Month?", False) (False, False)
# ('Does This Photo Capture a Skull-Like Face in the Clouds?', False) (False, False)
# ('Were USPS Mailboxes Removed in Oregon?', False) (True, False)
# ('Was a Woman Arrested for Stealing a Pumpkin and Hiding it in Her Vagina?', False) (False, False)
# ('Yes, Musk Decided to Let Donald Trump Back on Twitter', True) (True, True)
# ('Does Footage Show UFOs Flying Over Haiti and the Dominican Republic?', True) (False, True)
# ('Did Actor Keanu Reeves Save Dozens of Cats from Euthanasia?', False) (False, False)
# ('Do Photographs Show a Child Forced to Shoot His Dog?', True) (False, True)
# ("Are FedEx 'Set Delivery Preferences' Text Messages Real?", True) (True, True)
# ("Was Biden's Inauguration Crowd Smaller Than Trump's?", False) (False, False)
# ('Is This a Photograph of a Wasted Brett Kavanaugh?', True) (False, True)
# ("Is Daniel Radcliffe Starring in 'Harry Potter and the Cursed Child'?", False) (False, False)
# ("Seth Rich's Parents 'Thank' Internet for Spreading Rumor He Leaked Thousands of E-Mails to WikiLeaks?", False) (False, False)
# ("Just 100 Corporations Are Responsible for Majority of World's Greenhouse Gases?", False) (False, False)
# ('Trump Photoshopped His Hands to Look Bigger in White House Photograph?', False) (False, False)
# ("No, This Video Doesn't Show Iranian Father Dancing at His Daughter's Funeral", False) (True, False)
# ('Carjacker Run Over by Truck?', True) (True, True)
# ('No One Knows How Earth Got Its Name?', False) (False, False)
# ("No, Hobby Lobby's CEO Didn't Donate $14.88M to 'White Lives Matter'", True) (False, True)
# ('Sunny Oaks Elementary Forces Kids to Cross Dress for LGBT Week', False) (False, False)
# ('Bandits Posing as Gas Company Workers', False) (False, False)
# ("Did Biden Say Minorities Don't Know How To Register Online for Vaccines?", False) (False, False)
# ('Lion and Tiger and Bear, Oh My!', True) (True, True)
# ('Obamas at a White House Ball', False) (False, False)
# ("Is 'Price Is Right' Ending After Drew Carey Endorsed Keto?", True) (False, True)
# ('Imminent Changes Introduced to Texas Insurance Law in the Midst of Harvey?', True) (False, True)
# ('Yes, Skittles Is Bringing Back Its Lime Flavor', False) (True, False)
# ("Does a Photograph Depict a Huge Crowd at Trump's 2019 Orlando Rally?", False) (True, False)
# ('Did Trump Say He Loved Capitol Rioters in Now-Deleted Video?', False) (True, False)
# ('President Bush Bathroom Break Note', True) (True, True)
# ('Jill Biden Photo Was Doctored To Add Lobsters on Her Outfit', True) (False, True)
# ("Was an Orange County Supervisor Seriously Concerned About Vaccine 'Tracking Devices'?", False) (False, False)
# ('Sanders Campaign Busing Youths to Caucuses and Primaries', True) (False, True)
# ('Katy Perry Is JonBenét Ramsey?', True) (False, True)
# ("Bernie Sanders Wants to 'Dethrone God' and Destroy Capitalism?", False) (False, False)
# ('Does Germany Require You To Be Fully Vaccinated Before Receiving Assisted Suicide?', False) (False, False)
# ("Did Tampax Post This Tweet About Being 'In' Women?", True) (True, True)
# ("Did a Little Girl Have a 'Joker Smile' Carved Into Her Face in South Africa?", False) (False, False)
# ('Is This Mermaid TikTok Video Real?', False) (False, False)
# ('Ode to the Welfare State', True) (True, True)
# ("Did Merrick Garland Call Bill Barr a 'Liar' During Confirmation Hearing?", False) (False, False)
# ('Are Gasoline Prices Over $6.00 per Gallon in California?', False) (False, False)
# ("Did 'Irish Midget' Pose as Leprechaun in Pot of Gold for Sex Scheme?", False) (False, False)
# ("Is This a Real Photo of Elon Musk Holding a 'Trump Won' Flag?", True) (False, True)
# ("Did 71 Percent of Trump's Endorsements Lose in the 2018 Midterms?", False) (False, False)
# ("Did Members of the NYPD Wear 'I Can Breathe' Shirts in 2020 Protest?", True) (True, True)
# ("Did Abraham Lincoln's Ghost Appear in an 1872 Photo?", False) (False, False)
# ('Fan Belt', True) (True, True)
# ("Don't Selfie Your Ballot?", True) (False, True)
# ("Selena Gomez 'Made Disgusted Faces' and Covered Her Ears During Olivia Rodrigo's VMAs Performance?", False) (True, False)
# ('Israeli National Security Minister Posted About Hamas Loving Biden?', False) (True, False)
# ('Did a Sperm Whale Die After Swallowing 64 Pounds of Plastic Debris?', False) (True, False)
# ("No, AOC Didn't Tweet 'Farming Should Be Illegal'", True) (False, True)
# ("Lowe's Email Scam Promises 'Exclusive Reward'", True) (True, True)
# ('Coconut Crab', True) (True, True)
# ('Did Trump Issue Order Deeming Church an Essential Business?', True) (False, True)
# ('Size of the Indianapolis Motor Speedway', True) (True, True)
# ('Were News Stories About the Florida Mass Shooting Posted Days Before It Happened?', False) (False, False)
# ("Was an Austrian Police Officer Sentenced to Prison for Posting a Photo of Hitler's Favorite Meal?", True) (True, True)
# ('Did Kamala Harris Choose to be Sworn in with a Koran?', False) (False, False)
# ('Does Photo Show Bill Belichick Ordering at Chick-fil-A in Atlanta?', True) (True, True)
# ("Did 'Petey the Pelican' Befriend a Stray Dog?", True) (True, True)
# ('Cedar Point Free Ticket Scam', False) (True, False)
# ('Did a KGB Agent Confirm That the Sex Pistols Were Backed by the USSR to Destabilize the West?', False) (False, False)
# ('Malaysia MH370 Plane Found in Bermuda Triangle', False) (False, False)
# ("Is SpongeBob's Home Address on Epstein's 'Pedo Island'?", True) (False, True)
# ("Did Chelsea Clinton Tweet 'If Jesus Were Alive Today He'd Be Working at Planned Parenthood'?", True) (False, True)
# ("Whataburger 'Dollar Burger Day' Promotion", False) (False, False)
# ('Orphaned Drop Bear Cub Being Fed Human Blood?!', True) (False, True)
# ('Did a Gun Store Sell Trump-Shaped Dildos?', True) (False, True)
# ('Hurricane Lili', True) (False, True)
# ('FDA/Facebook Donations for National Hunger Awareness Month', False) (False, False)
# ('Do These Photographs Depict the Libyan Slave Trade?', False) (True, False)
# ('Does a Photo Show Sen. Chuck Schumer Kissing a Young Girl?', True) (False, True)
# ("Did Electronic Billboard in Moscow Display Putin Quote, 'Russia's Borders Do Not End Anywhere'?", False) (True, False)
# ("Is This Ghislaine Maxwell's Unsealed 'List of Names'?", False) (False, False)
# ('Did a Man from Zimbabwe Invent an Electric Car That Requires No Charging?', False) (False, False)
# ('Is Trump International Hotel Handing Out Anti-CNN Petitions?', False) (False, False)
# ("Do Facebook 'Copy and Paste, Don't Share' Posts Make Your Account Hackable?", True) (False, True)
# ("Is Rep. Marjorie Taylor Greene's Husband a 'Familiar' Celebrity?", False) (False, False)
# ("Is a 'Beware of Artists' Poster from the McCarthy Era?", False) (False, False)
# ('2005 Darwin Awards', False) (False, False)
# ('Does Photo Show Garlic-Flavored Coca-Cola?', True) (False, True)
# ("Did Robert Aaron Long Post China 'COVID Cover-Up' Message Before Mass Shooting?", False) (False, False)
# ("Did Democrats Refuse to Stand for a Navy SEAL's Widow?", True) (False, True)
# ('Did CNN Purchase an Industrial-Sized Washing Machine to Spin News?', True) (False, True)
# ("Is Steve Harvey Leaving 'Family Feud' After Endorsing CBD Gummies for Erectile Dysfunction?", False) (False, False)
# ('SCAM ALERT: Walmart Is Not Giving Away Vouchers To Celebrate Going Plastic Bag-Free', True) (True, True)
# ('Does This Photograph Show a Condor Killed in America?', True) (True, True)
# ("Ghazala Khan's Hijab Was a Political Stunt", False) (False, False)
# ('Southwest Airlines Las Vegas Ticket Giveaway Scam', True) (True, True)
# ("Melania Trump's Grandmother was a Soviet Soldier?", False) (False, False)
# ('Andrea Wilson, Facebook Friend Request Hacker Warning', True) (False, True)
# ('Was a Singaporean Woman Injured While Photocopying Her Breasts?', True) (False, True)
# ('Did Trump Say Governors Had To Treat Him Well To Get COVID-19 Supplies?', False) (False, False)
# ('The Eagle Has Landed', True) (True, True)
# ("Does a Photo Show a Parasite That Replaced a Fish's Tongue?", False) (True, False)
# ("Did Abraham Lincoln Say 'America Will Never Be Destroyed From the Outside'?", False) (False, False)
# ("'When You Need to Get Her Drunk'", False) (False, False)
# ("Did Thomas Edison Say, 'Our Greatest Weakness Lies in Giving Up'?", False) (True, False)
# ("Did the Steelers' James Harrison Threaten His Teammates?", False) (False, False)
# ("Is the Levi's Logo Racist?", True) (False, True)
# ("Are 'Blue Lives Murder' Shirts Available to Buy on Amazon?", True) (True, True)
# ("Photo Doesn't Show Crowd Giving Obama the Nazi Salute", True) (False, True)
# ('Fresno and Tulare Serial Killer Warning', False) (False, False)
# ('Did a Falcon Land Right in Front of a Camera Atop the Ambassador Bridge?', True) (True, True)
# ('Young Harriet Tubman Photograph', True) (False, True)
# ('Misspelled Martin Luther King Day Signs', False) (True, False)
# ("'Sam's Club Shopper Survey' Email Scam Promises Gift Card or 'Reward'", True) (True, True)
# ('Is This William Harley and Arthur Davidson Unveiling Their First Motorcycle?', True) (False, True)
# ('Real Photo of Chris Evans Signing Israeli Bomb Intended for Gaza?', False) (True, False)
# ('Are These Photos of Cicada Shell Art Real?', True) (True, True)
# ('Michael Burghardt', True) (True, True)
# ("Is This a Real Photo of Joe Biden Biting Jill Biden's Finger?", False) (True, False)
# ('Authentic Photo of Tunnel Between Rafah in Southern Gaza and Egypt?', True) (True, True)
# ('Is USPS Closing Soon Because of COVID-19?', False) (False, False)
# ('Did Facebook Posts Describe a Real Attempted Kidnapping Involving an Uber Driver in Tampa?', True) (False, True)
# ("Is Disney Making a Live-Action 'Hercules'?", True) (False, True)
# ('Kevin Hart Beaten at Miami Club', False) (False, False)
# ("Did Burger King Customers Tell Manager to 'Go Back to Your Mexican Country'?", False) (True, False)
# ('Einstein Bicycles as A-Bomb Explodes?', True) (False, True)
# ("Was Malia Obama 'Arrested Again' Amid a Media Blackout?", False) (False, False)
# ('Was Megyn Kelly Fired from NBC?', False) (False, False)
# ("Kid Rock Wears 'Dumbf*ckistan' T-Shirt", False) (False, False)
# ("Chef Gordon Ramsay Refused To Serve 'Woke Jackass' Robert De Niro?", False) (False, False)
# ("Did Justice Roberts Call Impeachment Vote 'Immoral and Possibly Illegal'?", False) (False, False)
# ('Did Steven Spielberg Get His Start by Sneaking Into an Empty Universal Studios Office?', False) (False, False)
# ("Is This the 'Most Detailed Image of a Human Cell to Date'?", False) (True, False)
# ("Is This a Photograph of a Venomous 'Asp' Caterpillar?", True) (True, True)
# ("'No DUIs' Scam Promises $610, $622, $710, or $712 in Savings", False) (True, False)
# ("Is This Photo of an Automobile 'Neck Belt' from the 1960s Real?", True) (False, True)
# ...
# ('Bacon Sandwich Reported as Offensive on Facebook', False) (False, False)
# ('Girl Kills Herself Facebook Scam', True) (False, True)
# ('Are These the Youngest Parents in the World?', True) (False, True)
# ('Trump Promises to Pardon Dylann Roof', False) (False, False)
# ('Pink Lady', False) (True, False)
# ('Does Photo Show Hillary Clinton Playing a Game Boy?', True) (True, True)
# ("Jordan Embry's Like Farm", True) (False, True)
# ('Send Money Now Scam', True) (False, True)
# ("Uniformed Veteran Kicked Out of Child's School", False) (False, False)
# ('Obama and the FBI -- Connect the Dots', True) (False, True)
# ('Marvin Smith Obituary', True) (True, True)
# ("Is the 'Why Ukraine Matters' Facebook Post Truthful?", True) (False, True)
# ('Did Tom Hanks Say He Would Leave US if Trump Wins 2024 Election?', False) (False, False)
# ("FBI Deleted Pride Month Post That Said, 'We Know That Diversity Makes Us Stronger'?", True) (False, True)
# ("Did Saudi Man Accidentally Buy 2 Airbus A350s for Son's Birthday?", False) (False, False)
# ("Did Chelsea Clinton Say Female Genital Mutilation Has 'Health Benefits'?", False) (False, False)
# ('Is This a Picture of Congressmembers Sitting During the Pledge of Allegiance?', True) (False, True)
# ("Is Mark Zuckerberg David Rockefeller's Grandson?", True) (False, True)
# ('Nepalese Baby', True) (True, True)
# ('Does This Photograph Show an Octopus Falling from the Sky in China?', True) (False, True)
# ('Trump Stared Directly at Sun During 2017 Solar Eclipse?', True) (True, True)
# ("Was a 'Pedophiles Are People Too' Notice Posted Near an Oregon School?", False) (False, False)
# ('Does This Photograph Show 66,000 People Outside a Trump Rally?', True) (False, True)
# ('Missing Child: Karissa Boudreau', True) (True, True)
# ("Did Willie 'Whoopass' Johnson Hit a Klansman?", False) (True, False)
# ('Is This a Photo of Trump With Former Mafia Hitman?', True) (True, True)
# ('Smartphone Pictures Pose Privacy Risks', True) (True, True)
# ("'Man Saves Her Baby' Ad About Mama Elephant Is Misleading", False) (False, False)
# ("Tweet Saying Nets 'Officially Released Kyrie Irving' Is Satire", True) (False, True)
# ('Is Trump Planning To Launch His Own Social Media Site?', True) (True, True)
# ('SCAM ALERT: Taco Bell Gift Cards and Coupons', False) (True, False)
# ("Was Emma González Wearing a Cuban Flag Patch During Her 'March for Our Lives' Speech?", False) (True, False)
# ("Did a Game Show Contestant Need Help Distinguishing Horsepower From 'Llamathrust'?", False) (True, False)
# ('Pic Shows Taylor Swift Eating Ice Cream as Children Cry?', False) (False, False)
# ('Is This a Photograph of Robert Mueller Meeting with Viktor Yanukovych?', True) (True, True)
# ('Is This a Photograph of a 12-Week Fetus?', False) (True, False)
# ("Was the COVID-19 Pandemic Planned in Rockefeller's 'Operation Lockstep'?", True) (False, True)
# ("Did Trump Promise 'Tremendous Stimulus Package Immediately After the Election'?", True) (True, True)
# ('Did a Netflix Film Poster Sexualize Young Girls?', True) (True, True)
# ('Heineken Beer', True) (False, True)
# ('Were 300 Children Found Frozen Alive for Organ Harvesting?', False) (False, False)
# ('Does a Video Show Needlessly Wasted Food at an Ohio Walmart?', True) (True, True)
# ('Did Twitter Become Profitable After Tesla Committed To Spending $10B on Ads?', False) (False, False)
# ('Are Flowers Blooming in Antarctica Because of Global Warming?', False) (True, False)
# ("Hillary Clinton Told 'Seventeen' Magazine She Didn't Want Her Daughter Marrying a Black Man?", True) (False, True)
# ("Did an Explosion at Al Franken's Montana Ranch Kill 6 People?", False) (False, False)
# ("Vladimir Putin Didn't Call Obama an Idiot for Socialist Policies", True) (False, True)
# ("Did Trump Retweet a Video Saying 'The Only Good Democrat is a Dead Democrat'?", True) (True, True)
# ("Does Video Show 'US Military Sending Huge Planes Full of Heavy-Duty Equipment to Israel' in 2023?", False) (True, False)
# ('Japanese American Girl Pledges Allegiance to US Flag Before WWII Incarceration?', True) (True, True)
# ("Did Sarah Huckabee Sanders Say She Was 'Proud' to be Compared to Aunt Lydia From 'The Handmaid's Tale'?", True) (False, True)
# ("Is a 'Less Than 50 Miles Per Day' Policy for Cars Real?", False) (False, False)
# ("Does This Photograph Show Pipe-Bombing Suspect Cesar Sayoc With a 'Known Democrat,' Proving a Hoax Conspiracy?", False) (False, False)
# ('No, This Is Not Kyle Rittenhouse Wearing KKK Garb as a Child', False) (False, False)
# ('Did a Mother Deer Sacrifice Herself to Cheetahs to Save Her Fawns?', True) (True, True)
# ("Did Donald Trump Say He Believes the UK Has 'Different Names'?", False) (False, False)
# ("Did Members of Ukraine's Armed Forces Help Make This Bollywood Video?", True) (True, True)
# ("Did Clint Eastwood's Net Worth Leave His Family 'in Tears'?", False) (False, False)
# ('Is Twitter Censoring the Ukrainian Flag Emoji?', True) (False, True)
# ("Did U.S. Sen. Mitch McConnell Increase His Net Worth by 'Nearly $2.4 Million Every Year for a Decade'?", False) (False, False)
# ("Does This Picture Show an Armored '2021 Dodge Ram'?", True) (True, True)
# ('Does a Photo Show a Trump Impeachment Rally in Toronto?', False) (True, False)
# ("Did Lester Holt 'Urge Journalists to Ditch Objectivity'?", True) (False, True)
# ('Did a U.S. Navy Ship Display This Crude Message Overhead to Iran?', False) (False, False)
# ('Was Biden Caught Using a Teleprompter During an Interview?', False) (False, False)
# ("The 'World's Loneliest House': Elliðaey's Myths Debunked", False) (False, False)
# ('David Letterman on President Bush', True) (False, True)
# ('Speed Trap', False) (True, False)
# ("Photograph 'Taken Without a Telescope' Shows Andromeda Galaxy Next to the Moon", True) (False, True)
# ('Did a Valedictorian Drop Out Just Before Graduating to Become a CEO?', False) (False, False)
# ("Do Vaccinated People 'Shed' COVID-19 Vaccine Particles?", True) (False, True)
# ('Does This Photograph Show Nolan Ryan Pitching After an On-Field Fight?', False) (True, False)
# ("Is Elon Musk Rebranding Twitter as 'X'?", True) (True, True)
# ("Are These Real Jen Psaki Tweets About Trump After Biden's Bike Fall?", False) (False, False)
# ('Is Andy Kaufman Still Alive?', True) (False, True)
# ("Was Joe Biden Refused Service at 'Crumb and Get It' in 2012?", False) (False, False)
# ("Does a Photograph Show Planned Parenthood's Founder at a KKK Rally?", True) (True, True)
# ('Bernie Sanders Suggests Election Is Rigged, Unendorses Hillary Clinton', False) (False, False)
# ('Is This a Real Airport Sign in India?', True) (False, True)
# ("Elon Musk Pulled Funding from Boy Scouts for Going 'Woke'?", False) (False, False)
# ('Floyd Mayweather Giving Away Money on Facebook?', True) (False, True)
# ("The 'Publix Branch Opening Promotion' for $8,000 Is a Scam", False) (True, False)
# ('Yes, a Pilot Really Did Survive Being Sucked Out of an Airplane in 1990', False) (True, False)
# ('Has SpongeBob SquarePants Been Cancelled?', True) (False, True)
# ('Is Photo of Melania Trump with Porn Star Ron Jeremy Real?', False) (False, False)
# ("Did Kathy Griffin Tell Jesus to 'Suck It'?", False) (True, False)
# ('Did George Soros Pay Refugees in Honduras to Join a Caravan and Storm the US Border?', False) (True, False)
# ('Burger King Vouchers Scam', True) (False, True)
# ('Is This Beyonce and Jay-Z Holding Their Twin Babies?', False) (False, False)
# ('Did Iranian Olympic Coverage Censor Images of Female Athletes?', False) (False, False)
# ('Donald Trump Compared Prep School to Military Service?', False) (True, False)
# ("Mike Pence Calls for a Ban on Condoms Because 'They Lead to Abortions'", False) (False, False)
# ("Does Texting 'USPS' to 50409 Send a Letter to Your Political Representatives?", True) (True, True)
# ('Striped Icebergs in Lake Michigan?', True) (True, True)
# ('Is This a Reindeer with Glow-in-the-Dark Antlers?', False) (True, False)
# ('Did Mark Twain Say This About Reading the Newspaper and Being Misinformed?', False) (False, False)
# ('Did Lindsey Graham Meet a Proud Boys Organizer Before Capitol Attack?', False) (False, False)
# ("What Is the 'Axel Panel Platform Bed' eBay Email?", False) (True, False)
# ("Is 'Trump' Tattooed on This Man's Forehead?", False) (False, False)
# ('Did Amy Coney Barrett Say This About Breastfeeding?', True) (False, True)
# ("Does This Photograph Depict an Actual 'Abortion Barbie' Doll?", True) (True, True)
# ('Viral Photo Shows Jim Carrey and Tupac Shakur Clubbing Together?', False) (False, False)
# ('Does the Zello Phone App Work Without the Internet?', True) (False, True)
# ("Does This Photo Show a 'Genius D-Day Invention'?", True) (True, True)
# ('Liger', True) (True, True)
# ("Do 'Angel Flights' Release Flare Salutes for Fallen Soldiers?", False) (True, False)
# ("Does Twitter's 'Like' Button Become an 'X' When You Press It?", False) (False, False)
# ("'USPS' Text Message Scam Claims Delivery Problem, Asks for Personal Financial Info", False) (True, False)
# ('Funny Face', True) (True, True)
# ('September 11 False Victims Scam', True) (True, True)
# ("Does 'Triscuit' Mean 'Electric Biscuit'?", True) (True, True)
# ("Did Barack Obama Mock President Trump's 'IDs for Groceries' Speech on Twitter?", True) (False, True)
# ('Were 50 Dead Bodies Found on a Beach in Cancun?', False) (False, False)
# ('Hillary Clinton Supporter Stands on American Flag', False) (False, False)
# ('Is This a Photograph of a Southeast African Monkey?', False) (False, False)
# ('Is This a Picture of a Male-Only Refugee Caravan Heading for U.S. Border?', False) (True, False)
# ('Donald Trump Browser Filter', True) (True, True)
# ('Did the President of Finland Post a Video Response to His White House Visit?', False) (False, False)
# ("Did Kamala Harris Say 'After Trump's Gone, We'll Be Coming for You Next'?", False) (False, False)
# ("No Proof Potential Juror's Tweet Cursing Trump Was Read Aloud at His Trial", False) (False, False)
# ('Did President Trump Sign an Executive Order Giving Veterans Free Care at Any Hospital?', False) (False, False)
# ('Did Greta Thunberg Delete Tweet Claiming Climate Change Will Wipe Out Humanity by 2023?', False) (False, False)
# ("Is 'Luciferase' the Name for the COVID-19 Vaccine?", True) (False, True)
# ("Does Trump Want to Make Mocking Jesus a 'Hate Crime'?", False) (False, False)
# ('Were Pearl Harbor Photographs Recently Found in an Old Camera?', False) (True, False)
# ("Muslim 'Religion of Peace' Demonstration", False) (False, False)
# ('Did an Electric Bus Catch Fire on Karen Road in Kenya?', True) (True, True)
# ("Does Meme Show the 'Very Moment' Yoko Ono Began 'Screeching' Near John Lennon and Chuck Berry?", False) (True, False)
# ("Does Trump Have a 12th Amendment 'Path to Victory'?", False) (False, False)
# ("Pic of Gas Generator Charging Tesla Wasn't Shot in U.S.", True) (True, True)
# ("Does a New Study Show the Higher a Country's Vaccination Rate, the Higher Its Excess Death Rate?", True) (False, True)
# ("Did Rush Limbaugh Call Troops 'Welfare Queens,' 'Moochers'?", True) (False, True)
# ('Is USPS Issuing No New Christmas Stamps in 2021?', False) (False, False)
# ('Is This a Real Video of Israeli Flag Displayed on the Las Vegas Sphere?', True) (False, True)
# ("Did Spirit Halloween Stores Sell 'Never Forget' 9/11 Family Costumes with Twin Towers and Airplane?", False) (False, False)
# ("Did the Flat Earth Society Post on Facebook It Has 'Members All Around the Globe'?", False) (False, False)
# ("Did Facebook Apologize for Removing 'Plymouth Hoe' Posts?", False) (True, False)
# ('Is This Trump in High-Waisted Pants?', True) (False, True)
# ("Is Kohl's Offering $250 Coupons to Social Media Users?", True) (True, True)
# ("Does a Photo Show Rioter Snatching a 'Podium' in the US Capitol?", False) (True, False)
# ('Is This a Picture of Elise Stefanik Flipping the Bird at an Impeachment Inquiry?', False) (False, False)
# ("Did Trump Endorse a Congressional Candidate Named 'Daniel N-Word'?", False) (False, False)
# ('Did Barack Obama Pardon More Than 330 Criminals During His Final Week in Office?', False) (False, False)
# ("Did Donald Trump Sign an Executive Order to Buy Ivanka's Chametz?", False) (False, False)
# ("A Texas Plumber's Truck Lands in Syria", False) (True, False)
# ('Does This Photograph Show an Eagle Cloud Over Jerusalem?', False) (True, False)
# ('Did Consumers Sue Over Alleged Hair Loss Ingredient in TRESemmé Shampoo?', True) (True, True)
# ('Was Anibe Alexandra Odoma Kidnapped In Houston?', True) (False, True)
# ("Whoopi Goldberg To Leave America with Megan Rapinoe: 'We Get No Respect Here'?", False) (False, False)
# ('Is This Eazy-E with Betty White?', True) (False, True)
# ('Is a Vintage Pearl Harbor Color Photograph Real?', False) (True, False)
# ('Authentic Photograph of Keanu Reeves Stealing Paparazzi Camera?', True) (True, True)
# ('Is This a Photograph of a Rare Marbled Fuark?', True) (False, True)
# ('Are 3 Previous US Presidents All Younger Than 2020 Candidates?', False) (True, False)
# ('Bowl-O-Bama', True) (False, True)
# ("Did JFK's Inaugural Parade Include Columns of Tanks?", False) (True, False)
# ("Did Maryland 'Deplorables' Erect a Billboard Warning About Attempts to Impeach Donald Trump?", False) (True, False)
# ("Is Taco Bell Roy Moore's Main Financial Backer?", False) (False, False)
# ('Does Suave Shampoo Contain an Ingredient That Causes Hair Loss?', True) (False, True)
# ('Milford Playground Sign', True) (True, True)
# ('Authentic 1923 Picture of Men Demonstrating Bulletproof Vest?', False) (True, False)
# ('Are Sex Traffickers Leaving Zip Ties on Cars, Mailboxes of Potential Victims?', False) (False, False)
# ("AOC Said 'You're a White Supremacist' If You Watch Tucker Carlson's Putin Interview?", False) (False, False)
# ('Was the Ballot of Deceased Man Named William Bradley Counted in Michigan?', True) (False, True)
# ("Was the El Paso Shooting Suspect's MyLife Page Altered by 'Leftists'?", True) (False, True)
# ("Avoid 'USPS' Email Scam Offering Contest Rewards", False) (True, False)
# ("Photo of Boy in Handcuffs Does Not Show 'GTA VI' Hacker", True) (True, True)
# ("Was a Woman With 'Chronic PMS' Arrested on Suspicion of 189 Murders?", True) (False, True)
# ("Is There a Problem with Brighton's Christmas Lights?", False) (False, False)
# ("Florida Sheriff Won't Remove 'In God We Trust' from Police Cars Despite Complaint?", False) (True, False)
# ('Is There a Link Between Major Hurricanes and 29 August?', False) (False, False)
# ('Does the U.S. Have the Third-Highest Rate of Homicides Worldwide?', True) (False, True)
# ('Did Musk Reinstate Trump on Twitter in April 2022?', True) (False, True)
# ('Escalator Threatened by Collapsed Shark Tank', False) (False, False)
# ('Is California Imposing a 5-Cent Tax on Text Messages to Fund Free Phones for Immigrants?', True) (False, True)
# ("Pictures Compares U.S. School Lunches to Other Countries'", False) (False, False)
# ('Eagle vs. Fox', True) (True, True)
# ('Does This Social Media Narrative Describe Volunteers Helping with Hurricane Dorian?', True) (False, True)
# ('Is This Lawmaker Drinking from a Chocolate Syrup Bottle?', True) (True, True)
# ('Snow in Egypt?', True) (False, True)
# ('Bicycle Tree', True) (True, True)
# ("Did LeBron James Tell NBA 'Dump the Anthem or I'll Quit'?", False) (False, False)
# ("Will Using the 'Wrong PIN' Protect You from Debit Card Fraud?", True) (False, True)
# ("Does Facebook 'Write Off' Your Birthday Donations?", True) (False, True)
# ('U.S. Flag on Canadian Currency', False) (False, False)
# ("Did Travis Kelce Tweet About 'Ugly Girls' and 'Fat People,' as Seen in Screenshots on Reddit and X?", False) (True, False)
# ('Will Eating an Egg and a Banana Kill You?', False) (False, False)
# ('Flathead Lake', True) (True, True)
# ('Kroger Free Coupon/Gift Card Scam', True) (True, True)
# ('DreamWeaverGrey Warning', True) (False, True)
# ('Day of the Dead Drone Art?', True) (False, True)
# ('Water Bridge', True) (True, True)
# ('Donald Trump, Melania Trump, and Stormy Daniels?', False) (False, False)
# ("'Don't Add' Warning", True) (False, True)
# ("Did Tim Tebow Write Apocalyptic Facebook Post About 'Cashless Society'?", False) (False, False)

# %% [markdown]
# ## Metrics

# %%
# tp = 0
# tn = 0
# fp = 0
# fn = 0

# for i in diffs:
#     matrix = f"{i[0]}{i[1]}"
#     match matrix:
#         case "11":
#             tp += 1
#         case "01":
#             fp += 1
#         case "10":
#             fn += 1
#         case "00":
#             tn += 1

# accuracy = (tp+tn)/len(diffs)
# specificity = tn/(fp+tn)
# recall = tp/(tp+fn)
# precision = tp/(tp+fp)
# f_score = 2 * ((precision * recall) / (precision + recall))

accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix: {cm}')
print(f'Classification Report: {report}')

# print(f"Acuracia = {accuracy}")
# print(f"Especificidade = {specificity}")
# print(f"Sensibilidade = {recall}")
# print(f"Precisão = {precision}")
# Out:
# Accuracy: 0.5699658703071673
# Confusion Matrix: [[414 322]
#  [182 254]]
# Classification Report:               precision    recall  f1-score   support
#
#        False       0.69      0.56      0.62       736
#         True       0.44      0.58      0.50       436
#
#     accuracy                           0.57      1172
#    macro avg       0.57      0.57      0.56      1172
# weighted avg       0.60      0.57      0.58      1172

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6c691cc8-2b4f-40d4-afcd-7c91cbe8e76d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
